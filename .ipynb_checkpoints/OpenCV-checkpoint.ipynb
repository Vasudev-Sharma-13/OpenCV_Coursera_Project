# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
img=Image.open("C://Users//vshar//OneDrive//Desktop//one.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=285x200>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_array = np.asarray(img)
type(img_array)
# Out:
# numpy.ndarray

# %%
plt.imshow(img_array)

# %%
img_array.shape
# Out:
# (200, 285, 3)

# %%
plt.imshow(img_array[:,:,0])

# %%
plt.imshow(img_array[:,:,1])

# %%
plt.imshow(img_array[:,:,2])

# %%
img_test  = img_arrar.copy()
img_test
